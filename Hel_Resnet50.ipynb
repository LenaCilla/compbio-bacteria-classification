# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Path to the images directory
images_path = 'PP_Micro'  # Adjust this path to your specific setup

# Function to load images from a directory
def load_images_from_folder(folder):
    images = []
    labels = []
    file_names = [f for f in os.listdir(folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    for filename in file_names:
        img = cv2.imread(os.path.join(folder, filename))
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
            images.append(img)
            labels.append(filename.split('_')[0])  # Assuming filename format is 'label_id.jpg'
    return images, labels

# Function to preprocess images
def preprocess_images(images, size=(224, 224)):
    images_resized = [cv2.resize(img, size) for img in images]
    images_normalized = np.array(images_resized) / 255.0  # Normalize pixel values
    return images_normalized

# %%
# Load and preprocess images
from tensorflow.keras.utils import to_categorical
images, labels = load_images_from_folder(images_path)
images_preprocessed = preprocess_images(images)

# Encode labels - simple numerical encoding and convert to one-hot
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)
labels_one_hot = to_categorical(labels_encoded)

# %%
import numpy as np
from sklearn.model_selection import KFold, train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load ResNet50 base model without the top
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model
base_model.trainable = False

# Create a new model on top
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(4096, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(8, activation='softmax')  # Assuming 3 classes for the task
])

model.summary()

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    min_lr=0.001,
    verbose=1
)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
import numpy as np
from sklearn.model_selection import KFold, train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Configuration
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

X_train, X_test, Y_train, Y_test = train_test_split(images_preprocessed, labels_one_hot, test_size=0.1, random_state=42)

# Prepare to collect scores
fold_no = 1
loss_per_fold = []
accuracy_per_fold = []

for train_idx, val_idx in kfold.split(X_train, Y_train):
    print(f'Training fold {fold_no}...')
    
    # Split data
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = Y_train[train_idx], Y_train[val_idx]

    # Fit the model
    history = model.fit(
        X_train_fold, y_train_fold,
        batch_size=32,
        epochs=20,
        verbose=1,
        validation_data=(X_val_fold, y_val_fold),
        callbacks=[early_stopping, reduce_lr]
    )

    # Evaluate the model
    scores = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f'Score for fold {fold_no}: Loss = {scores[0]}; Accuracy = {scores[1]*100}%')
    loss_per_fold.append(scores[0])
    accuracy_per_fold.append(scores[1] * 100)

    # Increment the fold number
    fold_no += 1

# Provide average scores
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(accuracy_per_fold)):
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {accuracy_per_fold[i]}%')
print('------------------------------------------------------------------------')
print(f'Average scores for all folds: Accuracy: {np.mean(accuracy_per_fold):.2f}%, Loss: {np.mean(loss_per_fold):.2f}')
print('------------------------------------------------------------------------')
# Out:
# Training fold 1...
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 18s 917ms/step - accuracy: 0.1465 - loss: 2.8765 - val_accuracy: 0.1949 - val_loss: 2.2295 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 797ms/step - accuracy: 0.1500 - loss: 2.3314 - val_accuracy: 0.1186 - val_loss: 2.3483 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 803ms/step - accuracy: 0.1813 - loss: 2.3993 - val_accuracy: 0.1356 - val_loss: 2.2606 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 806ms/step - accuracy: 0.1841 - loss: 2.2073 - val_accuracy: 0.1695 - val_loss: 2.0719 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 807ms/step - accuracy: 0.1927 - loss: 2.1029 - val_accuracy: 0.2203 - val_loss: 2.0746 - learning_rate: 0.0010
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 819ms/step - accuracy: 0.1586 - loss: 2.0576 - val_accuracy: 0.1525 - val_loss: 2.0493 - learning_rate: 0.0010
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 783ms/step - accuracy: 0.2018 - loss: 2.0143 - val_accuracy: 0.1525 - val_loss: 2.0380 - learning_rate: 0.0010
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 817ms/step - accuracy: 0.2203 - loss: 2.0053 - val_accuracy: 0.1102 - val_loss: 2.0865 - learning_rate: 0.0010
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.1759 - loss: 2.0620 - val_accuracy: 0.1356 - val_loss: 2.0924 - learning_rate: 0.0010
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.1750 - loss: 2.0584 - val_accuracy: 0.1441 - val_loss: 2.1019 - learning_rate: 0.0010
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.2067 - loss: 1.9575 - val_accuracy: 0.2288 - val_loss: 2.0002 - learning_rate: 0.0010
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.2126 - loss: 1.9766 - val_accuracy: 0.2288 - val_loss: 2.0060 - learning_rate: 0.0010
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.2019 - loss: 1.9577 - val_accuracy: 0.1610 - val_loss: 2.0485 - learning_rate: 0.0010
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.2334 - loss: 1.9902 - val_accuracy: 0.2034 - val_loss: 2.0102 - learning_rate: 0.0010
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 764ms/step - accuracy: 0.1937 - loss: 1.9496 - val_accuracy: 0.1949 - val_loss: 1.9936 - learning_rate: 0.0010
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 784ms/step - accuracy: 0.2251 - loss: 1.9297 - val_accuracy: 0.1610 - val_loss: 2.0531 - learning_rate: 0.0010
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 787ms/step - accuracy: 0.1881 - loss: 1.9680 - val_accuracy: 0.1271 - val_loss: 2.0308 - learning_rate: 0.0010
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 805ms/step - accuracy: 0.2411 - loss: 1.9127 - val_accuracy: 0.2288 - val_loss: 1.9837 - learning_rate: 0.0010
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 788ms/step - accuracy: 0.2136 - loss: 1.9593 - val_accuracy: 0.1525 - val_loss: 2.0515 - learning_rate: 0.0010
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 794ms/step - accuracy: 0.1948 - loss: 1.9762 - val_accuracy: 0.1441 - val_loss: 2.0468 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 18.
# Score for fold 1: Loss = 1.9836748838424683; Accuracy = 22.88135588169098%
# Training fold 2...
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 789ms/step - accuracy: 0.2519 - loss: 1.9352 - val_accuracy: 0.1780 - val_loss: 1.9445 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 792ms/step - accuracy: 0.2440 - loss: 1.9251 - val_accuracy: 0.2288 - val_loss: 1.9522 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 793ms/step - accuracy: 0.2288 - loss: 1.9433 - val_accuracy: 0.1610 - val_loss: 1.9877 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 784ms/step - accuracy: 0.2221 - loss: 1.9299 - val_accuracy: 0.2458 - val_loss: 1.9840 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 786ms/step - accuracy: 0.2267 - loss: 1.9326 - val_accuracy: 0.1525 - val_loss: 1.9937 - learning_rate: 0.0010
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 799ms/step - accuracy: 0.2450 - loss: 1.9194 - val_accuracy: 0.2797 - val_loss: 1.9258 - learning_rate: 0.0010
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 792ms/step - accuracy: 0.2494 - loss: 1.9464 - val_accuracy: 0.2119 - val_loss: 2.0170 - learning_rate: 0.0010
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 794ms/step - accuracy: 0.2518 - loss: 1.8984 - val_accuracy: 0.2373 - val_loss: 1.9448 - learning_rate: 0.0010
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 803ms/step - accuracy: 0.2595 - loss: 1.9172 - val_accuracy: 0.2288 - val_loss: 1.9317 - learning_rate: 0.0010
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 780ms/step - accuracy: 0.1875 - loss: 1.9448 - val_accuracy: 0.1610 - val_loss: 1.9781 - learning_rate: 0.0010
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 782ms/step - accuracy: 0.2715 - loss: 1.8824 - val_accuracy: 0.2542 - val_loss: 1.9559 - learning_rate: 0.0010
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Score for fold 2: Loss = 1.9257781505584717; Accuracy = 27.966102957725525%
# Training fold 3...
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 807ms/step - accuracy: 0.1800 - loss: 1.9920 - val_accuracy: 0.2458 - val_loss: 1.8629 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 806ms/step - accuracy: 0.2436 - loss: 1.9453 - val_accuracy: 0.1864 - val_loss: 1.8767 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 813ms/step - accuracy: 0.2429 - loss: 1.9461 - val_accuracy: 0.2034 - val_loss: 1.8901 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 808ms/step - accuracy: 0.2589 - loss: 1.9722 - val_accuracy: 0.1949 - val_loss: 1.8968 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 787ms/step - accuracy: 0.2604 - loss: 1.9277 - val_accuracy: 0.2966 - val_loss: 1.8705 - learning_rate: 0.0010
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 790ms/step - accuracy: 0.2618 - loss: 1.9528 - val_accuracy: 0.1949 - val_loss: 1.8964 - learning_rate: 0.0010
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Score for fold 3: Loss = 1.8629263639450073; Accuracy = 24.576270580291748%
# Training fold 4...
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 794ms/step - accuracy: 0.2281 - loss: 1.9299 - val_accuracy: 0.2373 - val_loss: 1.9149 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 783ms/step - accuracy: 0.2071 - loss: 1.9549 - val_accuracy: 0.2203 - val_loss: 1.9385 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 796ms/step - accuracy: 0.2181 - loss: 1.9949 - val_accuracy: 0.2966 - val_loss: 1.8834 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 788ms/step - accuracy: 0.2144 - loss: 1.9238 - val_accuracy: 0.3136 - val_loss: 1.9100 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 789ms/step - accuracy: 0.2665 - loss: 1.8978 - val_accuracy: 0.3475 - val_loss: 1.8829 - learning_rate: 0.0010
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Score for fold 4: Loss = 1.9149214029312134; Accuracy = 23.728813230991364%
# Training fold 5...
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 809ms/step - accuracy: 0.2241 - loss: 1.9542 - val_accuracy: 0.2137 - val_loss: 1.9115 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 791ms/step - accuracy: 0.2157 - loss: 1.9530 - val_accuracy: 0.2564 - val_loss: 1.9243 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 787ms/step - accuracy: 0.2400 - loss: 1.9418 - val_accuracy: 0.2821 - val_loss: 1.9089 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 813ms/step - accuracy: 0.2657 - loss: 1.9263 - val_accuracy: 0.2308 - val_loss: 1.9219 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 797ms/step - accuracy: 0.2621 - loss: 1.8755 - val_accuracy: 0.2137 - val_loss: 1.9068 - learning_rate: 0.0010
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Score for fold 5: Loss = 1.9115102291107178; Accuracy = 21.367521584033966%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 1.9836748838424683 - Accuracy: 22.88135588169098%
# > Fold 2 - Loss: 1.9257781505584717 - Accuracy: 27.966102957725525%
# > Fold 3 - Loss: 1.8629263639450073 - Accuracy: 24.576270580291748%
# > Fold 4 - Loss: 1.9149214029312134 - Accuracy: 23.728813230991364%
# > Fold 5 - Loss: 1.9115102291107178 - Accuracy: 21.367521584033966%
# ------------------------------------------------------------------------
# Average scores for all folds: Accuracy: 24.10%, Loss: 1.92
# ------------------------------------------------------------------------

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_val_fold, y_val_fold)
print(f"Validation accuracy: {test_accuracy}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 528ms/step - accuracy: 0.2313 - loss: 1.9107
# Validation accuracy: 0.21367521584033966

# %%
# Plot training & test accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & test loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(np.argmax(y_val_fold, axis=1), np.argmax(model.predict(X_val_fold),axis=1)))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 864ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.12      0.19      0.15        16
#            2       0.43      0.18      0.25        17
#            3       0.20      0.71      0.31        17
#            4       0.19      0.25      0.22        16
#            5       1.00      0.23      0.38        13
#            6       0.00      0.00      0.00        14
#            7       0.00      0.00      0.00        12
#
#     accuracy                           0.21       117
#    macro avg       0.24      0.19      0.16       117
# weighted avg       0.24      0.21      0.17       117
# c:\Users\Tricks\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Tricks\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Tricks\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
y_true = np.argmax(y_val_fold, axis=1)
y_pred = np.argmax(model.predict(X_val_fold), axis=1)
data = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(data, columns=np.unique(y_true), index = np.unique(y_true))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (30,20))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 525ms/step
# <Axes: xlabel='Predicted', ylabel='Actual'>

# %%
rand_n = np.random.randint(X_val_fold.shape[0])
plt.imshow(X_val_fold[rand_n][:, :, 0], cmap='gray')
plt.title(f'Actual:{np.argmax(y_val_fold[rand_n])} Predicted: {np.argmax(model.predict(X_val_fold[rand_n].reshape(-1, 224, 224, 3)))}');
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
